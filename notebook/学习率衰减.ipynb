# %%
from __future__ import print_function, division
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
epoch = np.arange(1,21,1)
lr = 1e-2  # 初始学习率
lr_end = 1e-3

# %% [markdown]
# #### 方法1
#
# $$
# \alpha = \frac{1}{1+decayrate \times epoch} \alpha_0
# $$

# %%
decayrate = 0.1
y1 = lr / (1+decayrate*epoch)
decayrate = 0.2
y2 = lr / (1+decayrate*epoch)
plt.plot(epoch, y1, epoch, y2)
plt.legend(["y1","y2"])
plt.show()

# %% [markdown]
# #### 方法2
#
# $\alpha_0:$初始学习率
#
# $$
# \alpha = 0.95^{epoch} \alpha_0
# $$

# %%
y1 = lr_init * np.power(0.95,epoch)
y2 = lr_init * np.power(0.9,epoch)
#plt.scatter(0, lr)
plt.plot(epoch, y1, epoch, y2)
plt.legend(["y1","y2"])
plt.show()

# %% [markdown]
# #### 方法3
#
# $$
# \alpha = \frac{k}{\sqrt{epoch}} \alpha_0
# $$

# %%
k = 1
y1 = lr*k / np.sqrt(epoch)
k = 0.8
y2 = lr*k / np.sqrt(epoch)
plt.plot(epoch, y1, epoch, y2)
plt.legend(["y1","y2"])
plt.show()
